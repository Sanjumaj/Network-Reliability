# %%
import matplotlib.pyplot as plt

# %%
Reliabilities=[1.274200585937502E-6 ,6.961240000000008E-5 ,6.728452154296899E-4 ,0.00318760959999999 ,0.010183334350585938 ,
               0.025280553599999988 ,0.05259018298105454 ,0.09587261439999974 ,0.15762072973183672 ,0.23828124999999997 ,
               0.33579627347793106 ,0.44558346239999974 ,0.5609911623443362 ,0.6741758295999962 ,0.777265548706055 ,0.8636071936000037 ,
               0.9288579701880857 ,0.9716867244000013 ,0.9939085566654368 ,1.0 ]

# %%
Probabilities = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.90, 0.95, 1.00 ]

# %%
plt.plot(Probabilities, Reliabilities,marker='o')
plt.xlabel('p value')
plt.ylabel('Network Reliability')
plt.title('The Dependency plot of network reliability on the value of p')
plt.grid(True)
